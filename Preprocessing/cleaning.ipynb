# %% [markdown]
# # **PRÉ-PROCESSAMENTO DOS DADOS**

# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv(r'C:\Users\João Pedro\Documents\UFG\MD\estudo_caso\data\UCMF_raw.csv')
df.head()
# Out:
#    ID  Peso  Altura   IMC Atendimento        DN  IDADE Convenio   PULSOS  \
# 0   1   5.0      51  19.0    11/05/06  30/03/06   0.12       GS  Normais
# 1   2   3.5      50  14.0    25/05/05  19/05/05   0.02       GS  Normais
# 2   3   0.0       0   NaN    12/06/01  08/05/05  -4.05     SULA  Normais
# 3   4   8.1      65  19.0    15/10/09  21/04/09   0.50      NaN  Normais
# 4   7  40.0     151  18.0    14/01/08  14/08/95  12.89     SAME  Normais
#
#    PA SISTOLICA  ...            PPA NORMAL X ANORMAL      B2      SOPRO   FC  \
# 0           NaN  ...  Não Calculado          Anormal  Normal  Sistólico  112
# 1           NaN  ...  Não Calculado          Anormal  Normal    ausente  128
# 2           NaN  ...  Não Calculado          Anormal  Normal  Sistólico   88
# 3           NaN  ...  Não Calculado          Anormal  Normal    ausente   92
# 4           NaN  ...  Não Calculado          Anormal  Normal    ausente   96
#
#             HDA 1 HDA2 SEXO                      MOTIVO1  \
# 0      Palpitacao  NaN    M  6 - Suspeita de cardiopatia
# 1        Dispneia  NaN    M  6 - Suspeita de cardiopatia
# 2   Assintomático  NaN    M                 2 - Check-up
# 3   Assintomático  NaN    M     5 - Parecer cardiológico
# 4  Dor precordial  NaN    M     5 - Parecer cardiológico
#
#                                MOTIVO2
# 0  6 - Palpitação/taquicardia/arritmia
# 1                         6 - Dispnéia
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Retirando a coluna *ID*

# %%
df_copy = df.copy()
df_copy.drop(columns=['ID', 'Convenio', 'SEXO'], inplace=True)
df_copy.head()
# Out:
#    Peso  Altura   IMC Atendimento        DN  IDADE   PULSOS  PA SISTOLICA  \
# 0   5.0      51  19.0    11/05/06  30/03/06   0.12  Normais           NaN
# 1   3.5      50  14.0    25/05/05  19/05/05   0.02  Normais           NaN
# 2   0.0       0   NaN    12/06/01  08/05/05  -4.05  Normais           NaN
# 3   8.1      65  19.0    15/10/09  21/04/09   0.50  Normais           NaN
# 4  40.0     151  18.0    14/01/08  14/08/95  12.89  Normais           NaN
#
#    PA DIASTOLICA            PPA NORMAL X ANORMAL      B2      SOPRO   FC  \
# 0            NaN  Não Calculado          Anormal  Normal  Sistólico  112
# 1            NaN  Não Calculado          Anormal  Normal    ausente  128
# 2            NaN  Não Calculado          Anormal  Normal  Sistólico   88
# 3            NaN  Não Calculado          Anormal  Normal    ausente   92
# 4            NaN  Não Calculado          Anormal  Normal    ausente   96
#
#             HDA 1 HDA2                      MOTIVO1  \
# 0      Palpitacao  NaN  6 - Suspeita de cardiopatia
# 1        Dispneia  NaN  6 - Suspeita de cardiopatia
# 2   Assintomático  NaN                 2 - Check-up
# 3   Assintomático  NaN     5 - Parecer cardiológico
# 4  Dor precordial  NaN     5 - Parecer cardiológico
#
#                                MOTIVO2
# 0  6 - Palpitação/taquicardia/arritmia
# 1                         6 - Dispnéia
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %% [markdown]
# ## Retirar linhas ou colunas com mais de 50% de dados faltantes

# %%
(df_copy.isna().mean() * 100).sort_values(ascending=False)
# Out:
# HDA2                96.631631
# IMC                 32.599520
# HDA 1               28.833899
# Convenio            27.551105
# MOTIVO2             22.428205
# FC                   8.921625
# IDADE                5.867748
# DN                   4.874617
# PULSOS               3.376645
# NORMAL X ANORMAL     3.285608
# B2                   3.252504
# SOPRO                3.186295
# Peso                 2.623521
# MOTIVO1              2.234544
# PPA                  1.795912
# Atendimento          1.704875
# SEXO                 0.033104
# Altura               0.000000
# dtype: float64

# %%
df_copy.drop(columns=['PA DIASTOLICA', 'PA SISTOLICA'], inplace=True)

# %%
# 1. Calcula a porcentagem de nulos para cada linha
percentual_nulos_linha = df_copy.isna().mean(axis=1)

# 2. Filtra apenas as linhas com mais de 50% (0.5) de nulos
linhas_vazias = df_copy[percentual_nulos_linha > 0.5]

# Mostra quantas linhas foram encontradas
print(f"Foram encontradas {len(linhas_vazias)} linhas com mais de 50% de dados faltantes.")

# Visualiza essas linhas (mostrando apenas as primeiras 5 para não poluir a tela)
linhas_vazias.head()
# Out:
# Foram encontradas 790 linhas com mais de 50% de dados faltantes.
#      Peso  Altura  IMC Atendimento   DN  IDADE Convenio PULSOS      PPA  \
# 46    0.0       0  NaN         NaN  NaN    NaN      NaN    NaN  #VALUE!
# 60    0.0       0  NaN         NaN  NaN    NaN      NaN    NaN  #VALUE!
# 94    0.0       0  NaN         NaN  NaN    NaN      NaN    NaN  #VALUE!
# 117   0.0       0  NaN         NaN  NaN    NaN      NaN    NaN  #VALUE!
# 118   0.0       0  NaN         NaN  NaN    NaN      NaN    NaN  #VALUE!
#
#     NORMAL X ANORMAL   B2 SOPRO   FC HDA 1 HDA2           SEXO MOTIVO1 MOTIVO2
# 46               NaN  NaN   NaN  NaN   NaN  NaN  Indeterminado     NaN     NaN
# 60               NaN  NaN   NaN  NaN   NaN  NaN  Indeterminado     NaN     NaN
# 94               NaN  NaN   NaN  NaN   NaN  NaN  Indeterminado     NaN     NaN
# 117              NaN  NaN   NaN  NaN   NaN  NaN  Indeterminado     NaN     NaN
# 118              NaN  NaN   NaN  NaN   NaN  NaN  Indeterminado     NaN     NaN

# %%
# 1. Identifica os índices das linhas com mais de 50% (0.5) de nulos
linhas_para_remover = df_copy[df_copy.isna().mean(axis=1) > 0.5].index

# 2. Remove as linhas usando .drop()
df_copy.drop(linhas_para_remover, inplace=True)

# 3. Feedback para você saber quantas foram apagadas
print(f"Foram removidas {len(linhas_para_remover)} linhas.")
# Out:
# Foram removidas 790 linhas.

# %% [markdown]
# ## Tratando a coluna *Idade*

# %%
def limpar_data(val):
    try:
        # Tenta converter formato dia/mês/ano
        return pd.to_datetime(val, format='%d/%m/%y')
    except:
        try:
            # Se falhar, tenta converter número serial do Excel
            # (Base do Excel é aprox 30/12/1899)
            return pd.to_datetime(float(val), unit='D', origin='1899-12-30')
        except:
            return pd.NaT
    
df['DN_limpa'] = df['DN'].apply(limpar_data)
df['Atendimento_limpa'] = df['Atendimento'].apply(limpar_data)
df_copy.head()
# Out:
#    Peso  Altura   IMC Atendimento        DN  IDADE   PULSOS  PA SISTOLICA  \
# 0   5.0      51  19.0    11/05/06  30/03/06   0.12  Normais           NaN
# 1   3.5      50  14.0    25/05/05  19/05/05   0.02  Normais           NaN
# 2   0.0       0   NaN    12/06/01  08/05/05  -4.05  Normais           NaN
# 3   8.1      65  19.0    15/10/09  21/04/09   0.50  Normais           NaN
# 4  40.0     151  18.0    14/01/08  14/08/95  12.89  Normais           NaN
#
#    PA DIASTOLICA            PPA NORMAL X ANORMAL      B2      SOPRO   FC  \
# 0            NaN  Não Calculado          Anormal  Normal  Sistólico  112
# 1            NaN  Não Calculado          Anormal  Normal    ausente  128
# 2            NaN  Não Calculado          Anormal  Normal  Sistólico   88
# 3            NaN  Não Calculado          Anormal  Normal    ausente   92
# 4            NaN  Não Calculado          Anormal  Normal    ausente   96
#
#             HDA 1 HDA2                      MOTIVO1  \
# 0      Palpitacao  NaN  6 - Suspeita de cardiopatia
# 1        Dispneia  NaN  6 - Suspeita de cardiopatia
# 2   Assintomático  NaN                 2 - Check-up
# 3   Assintomático  NaN     5 - Parecer cardiológico
# 4  Dor precordial  NaN     5 - Parecer cardiológico
#
#                                MOTIVO2
# 0  6 - Palpitação/taquicardia/arritmia
# 1                         6 - Dispnéia
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %% [markdown]
# ## Tratando a coluna *NORMAL X ANORMAL*

# %%
df_copy[(df_copy['NORMAL X ANORMAL'].isna()) & (df_copy['SOPRO'] != 'ausente') & (df_copy['SOPRO'].notna())]
# Out:
#        Peso  Altura   IMC Atendimento        DN  IDADE Convenio   PULSOS  \
# 1353    0.0       0   NaN         NaN       NaN    NaN      NaN      NaN
# 1730    0.0       0   NaN         NaN       NaN    NaN      NaN      NaN
# 12589   5.3      60  15.0    02/12/08  13/09/08   0.23      NaN  Normais
# 12615   0.0       0   NaN    12/05/08  18/06/99   9.24      NaN  Normais
# 12687   0.0       0   NaN    16/06/09  10/03/04   5.47      NaN  Normais
# 12747  46.0     162  18.0    04/08/03  08/04/89  14.86       UR  Normais
# 12757  20.0       0   NaN    01/07/03  17/12/96   6.78       GS  Normais
# 12766  24.0     118  17.0    17/02/09  14/09/03   5.63      NaN  Normais
# 12854  30.0       0   NaN    22/08/06       NaN    NaN       GS  Normais
#
#        PA SISTOLICA  PA DIASTOLICA            PPA NORMAL X ANORMAL      B2  \
# 1353            NaN            NaN        #VALUE!              NaN     NaN
# 1730            NaN            NaN        #VALUE!              NaN     NaN
# 12589           NaN            NaN  Não Calculado              NaN  Normal
# 12615         100.0           60.0  Não Calculado              NaN  Normal
# 12687           NaN            NaN  Não Calculado              NaN  Normal
# 12747          90.0           60.0  Não Calculado              NaN  Normal
# 12757          90.0           60.0  Não Calculado              NaN  Normal
# 12766         100.0           60.0  Não Calculado              NaN  Normal
# 12854         140.0           60.0        #VALUE!              NaN  Normal
#
#            SOPRO   FC          HDA 1     HDA2  SEXO  \
# 1353    Contínuo  NaN            NaN      NaN   2.0
# 1730   Sistólico  NaN            NaN      NaN   2.0
# 12589  Sistólico  100  Assintomático      NaN   1.0
# 12615  Sistólico   90  Assintomático      NaN   0.0
# 12687  Sistólico   90  Assintomático      NaN   0.0
# 12747  Sistólico   90  Assintomático      NaN   0.0
# 12757  Sistólico  100  Assintomático      NaN   0.0
# 12766  Sistólico   78  Assintomático      NaN   0.0
# 12854  Sistólico  120       Dispneia  Cianose   1.0
#
#                                MOTIVO1                    MOTIVO2
# 1353                               NaN                        NaN
# 1730                               NaN                        NaN
# 12589      6 - Suspeita de cardiopatia                  6 - Sopro
# 12615  1 - Cardiopatia já estabelecida  1 - Cardiopatia congenica
# 12687      6 - Suspeita de cardiopatia                      Outro
# 12747                     2 - Check-up                        NaN
# 12757      6 - Suspeita de cardiopatia                  6 - Sopro
# 12766      6 - Suspeita de cardiopatia                  6 - Sopro
# 12854         5 - Parecer cardiológico                      Outro

# %%
df_copy.dropna(subset=['NORMAL X ANORMAL'], inplace=True)

# %%
df_copy.head()
# Out:
#    Peso  Altura   IMC Atendimento        DN  IDADE Convenio   PULSOS  \
# 0   5.0      51  19.0    11/05/06  30/03/06   0.12       GS  Normais
# 1   3.5      50  14.0    25/05/05  19/05/05   0.02       GS  Normais
# 2   0.0       0   NaN    12/06/01  08/05/05  -4.05     SULA  Normais
# 3   8.1      65  19.0    15/10/09  21/04/09   0.50      NaN  Normais
# 4  40.0     151  18.0    14/01/08  14/08/95  12.89     SAME  Normais
#
#    PA SISTOLICA  PA DIASTOLICA            PPA NORMAL X ANORMAL      B2  \
# 0           NaN            NaN  Não Calculado          Anormal  Normal
# 1           NaN            NaN  Não Calculado          Anormal  Normal
# 2           NaN            NaN  Não Calculado          Anormal  Normal
# 3           NaN            NaN  Não Calculado          Anormal  Normal
# 4           NaN            NaN  Não Calculado          Anormal  Normal
#
#        SOPRO   FC           HDA 1 HDA2  SEXO                      MOTIVO1  \
# 0  Sistólico  112      Palpitacao  NaN   1.0  6 - Suspeita de cardiopatia
# 1    ausente  128        Dispneia  NaN   1.0  6 - Suspeita de cardiopatia
# 2  Sistólico   88   Assintomático  NaN   1.0                 2 - Check-up
# 3    ausente   92   Assintomático  NaN   1.0     5 - Parecer cardiológico
# 4    ausente   96  Dor precordial  NaN   1.0     5 - Parecer cardiológico
#
#                                MOTIVO2
# 0  6 - Palpitação/taquicardia/arritmia
# 1                         6 - Dispnéia
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %% [markdown]
# ## Tratando coluna *Pulsos*

# %%
df_copy['PULSOS'].isna().sum()
# Out:
# np.int64(48)

# %%
df_copy.loc[df_copy['PULSOS'].isna(), ['SOPRO', 'PULSOS', 'PPA', 'PA SISTOLICA', 'PA DIASTOLICA', 'FC', 'NORMAL X ANORMAL', 'B2', 'HDA 1']]
# Out:
#             SOPRO PULSOS            PPA  PA SISTOLICA  PA DIASTOLICA   FC  \
# 57      Sistólico    NaN  Não Calculado         100.0           60.0  NaN
# 65      sistólico    NaN  Não Calculado           NaN            NaN  100
# 84      sistólico    NaN  Não Calculado           NaN            NaN  200
# 161     sistólico    NaN  Não Calculado           NaN            NaN  164
# 167     sistólico    NaN  Não Calculado           NaN            NaN  152
# 185       ausente    NaN  Não Calculado           NaN            NaN  112
# 268       ausente    NaN  Não Calculado           NaN            NaN  100
# 371       ausente    NaN  Não Calculado           NaN            NaN  120
# 403     sistólico    NaN         Normal          90.0           55.0   80
# 409       ausente    NaN  Não Calculado           NaN            NaN  140
# 418     sistólico    NaN  Não Calculado           NaN            NaN  160
# 443     sistólico    NaN      HAS-2 PAS         130.0           70.0   84
# 450     sistólico    NaN         Normal         110.0           70.0   80
# 517       ausente    NaN  Não Calculado           NaN            NaN  100
# 536     Sistólico    NaN        #VALUE!           NaN            NaN  NaN
# 594       ausente    NaN  Não Calculado           NaN            NaN  100
# 617       ausente    NaN         Normal         100.0           60.0   80
# 626       ausente    NaN  Não Calculado           NaN            NaN  300
# 696     sistólico    NaN  Não Calculado          90.0           60.0   88
# 744    diastólico    NaN  Não Calculado         110.0           50.0  NaN
# 806       ausente    NaN  Não Calculado         100.0           65.0   80
# 1143      ausente    NaN        #VALUE!           NaN            NaN   80
# 1154     Contínuo    NaN            NaN         100.0           60.0   90
# 1254      ausente    NaN        #VALUE!           NaN            NaN  NaN
# 5024    Sistólico    NaN  Não Calculado         110.0           70.0   80
# 5119      ausente    NaN  Não Calculado           NaN            NaN   90
# 12562         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12578         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12581         NaN    NaN  Não Calculado           NaN            NaN  NaN
# 12590         NaN    NaN  Não Calculado           NaN            NaN  NaN
# 12607         NaN    NaN  Não Calculado           NaN            NaN  NaN
# 12616         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12634         NaN    NaN  Não Calculado           NaN            NaN  NaN
# 12636         NaN    NaN  Não Calculado           NaN            NaN  NaN
# 12662         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12667         NaN    NaN  Não Calculado           NaN            NaN  NaN
# 12688         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12708         NaN    NaN  Não Calculado           NaN            NaN  NaN
# 12738         NaN    NaN  Não Calculado           NaN            NaN  NaN
# 12748         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12758         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12763         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12767         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12782         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12803         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12833         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12839         NaN    NaN        #VALUE!           NaN            NaN  NaN
# 12855         NaN    NaN        #VALUE!           NaN            NaN  NaN
#
#       NORMAL X ANORMAL             B2          HDA 1
# 57             Anormal         Normal          Outro
# 65             Anormal         Normal            NaN
# 84             Anormal         Normal            NaN
# 161            Anormal         Normal       Dispneia
# 167            Anormal         Normal       Dispneia
# 185             Normal         Normal            NaN
# 268            Anormal  Hiperfonética            NaN
# 371             Normal         Normal  Assintomático
# 403             Normal         Normal            NaN
# 409             Normal         Normal  Assintomático
# 418            Anormal          Única            NaN
# 443            Anormal         Normal  Assintomático
# 450            Anormal         Normal            NaN
# 517             Normal         Normal            NaN
# 536            Anormal  Hiperfonética            NaN
# 594             Normal         Normal            NaN
# 617             Normal         Normal            NaN
# 626            Anormal         Normal       Dispneia
# 696            Anormal  Hiperfonética            NaN
# 744            Anormal  Hiperfonética            NaN
# 806             Normal         Normal            NaN
# 1143            Normal         Normal            NaN
# 1154           Anormal  Hiperfonética       Dispneia
# 1254           Anormal  Hiperfonética       Dispneia
# 5024           Anormal  Hiperfonética  Assintomático
# 5119            Normal         Normal  Assintomático
# 12562          Anormal            NaN            NaN
# 12578          Anormal            NaN            NaN
# 12581          Anormal            NaN            NaN
# 12590           Normal            NaN  Assintomático
# 12607           Normal            NaN            NaN
# 12616          Anormal            NaN            NaN
# 12634           Normal            NaN            NaN
# 12636           Normal            NaN            NaN
# 12662           Normal            NaN            NaN
# 12667           Normal            NaN            NaN
# 12688          Anormal            NaN            NaN
# 12708           Normal            NaN            NaN
# 12738           Normal            NaN            NaN
# 12748           Normal            NaN            NaN
# 12758           Normal            NaN            NaN
# 12763          Anormal            NaN            NaN
# 12767          Anormal            NaN            NaN
# 12782           Normal            NaN            NaN
# 12803           Normal            NaN            NaN
# 12833           Normal            NaN            NaN
# 12839           Normal            NaN            NaN
# 12855           Normal            NaN            NaN

# %%
df_copy[(df_copy['PULSOS'].isna()) & (df_copy['NORMAL X ANORMAL'] == 'Anormal')]
# Out:
#        Peso  Altura   IMC Atendimento  IDADE PULSOS  PA SISTOLICA  \
# 57     32.0       0   NaN    06/08/03  10.16    NaN         100.0
# 65      7.1      67  16.0       38185   0.43    NaN           NaN
# 84      0.0       0   NaN    15/04/09   0.13    NaN           NaN
# 161     5.0       0   NaN    12/03/08   0.11    NaN           NaN
# 167     0.0       0   NaN    08/01/04   0.10    NaN           NaN
# 268     0.0      62   0.0    07/03/06   0.49    NaN           NaN
# 418     0.0       0   NaN    22/09/08   1.34    NaN           NaN
# 443    28.0     138  15.0    28/09/07  10.41    NaN         130.0
# 450    37.0     151  16.0    25/10/04  11.90    NaN         110.0
# 536     0.0       0   NaN         NaN    NaN    NaN           NaN
# 626     0.0       0   NaN    01/08/07   0.03    NaN           NaN
# 696    17.0       0   NaN    06/10/04   7.72    NaN          90.0
# 744    20.0       0   NaN    21/05/07   8.81    NaN         110.0
# 1154   45.0     170  16.0    09/02/10  17.53    NaN         100.0
# 1254    0.0       0   NaN    23/12/04    NaN    NaN           NaN
# 5024    0.0       0   NaN    03/04/03  10.49    NaN         110.0
# 12562   0.0       0   NaN         NaN    NaN    NaN           NaN
# 12578   0.0       0   NaN         NaN    NaN    NaN           NaN
# 12581  85.0     151  37.0    27/10/03  11.82    NaN           NaN
# 12616   0.0       0   NaN         NaN    NaN    NaN           NaN
# 12688   0.0       0   NaN         NaN    NaN    NaN           NaN
# 12763   0.0       0   NaN         NaN    NaN    NaN           NaN
# 12767   0.0       0   NaN         NaN    NaN    NaN           NaN
#
#        PA DIASTOLICA            PPA NORMAL X ANORMAL             B2  \
# 57              60.0  Não Calculado          Anormal         Normal
# 65               NaN  Não Calculado          Anormal         Normal
# 84               NaN  Não Calculado          Anormal         Normal
# 161              NaN  Não Calculado          Anormal         Normal
# 167              NaN  Não Calculado          Anormal         Normal
# 268              NaN  Não Calculado          Anormal  Hiperfonética
# 418              NaN  Não Calculado          Anormal          Única
# 443             70.0      HAS-2 PAS          Anormal         Normal
# 450             70.0         Normal          Anormal         Normal
# 536              NaN        #VALUE!          Anormal  Hiperfonética
# 626              NaN  Não Calculado          Anormal         Normal
# 696             60.0  Não Calculado          Anormal  Hiperfonética
# 744             50.0  Não Calculado          Anormal  Hiperfonética
# 1154            60.0            NaN          Anormal  Hiperfonética
# 1254             NaN        #VALUE!          Anormal  Hiperfonética
# 5024            70.0  Não Calculado          Anormal  Hiperfonética
# 12562            NaN        #VALUE!          Anormal            NaN
# 12578            NaN        #VALUE!          Anormal            NaN
# 12581            NaN  Não Calculado          Anormal            NaN
# 12616            NaN        #VALUE!          Anormal            NaN
# 12688            NaN        #VALUE!          Anormal            NaN
# 12763            NaN        #VALUE!          Anormal            NaN
# 12767            NaN        #VALUE!          Anormal            NaN
#
#             SOPRO   FC          HDA 1     HDA2  \
# 57      Sistólico  NaN          Outro      NaN
# 65      sistólico  100            NaN      NaN
# 84      sistólico  200            NaN      NaN
# 161     sistólico  164       Dispneia      NaN
# 167     sistólico  152       Dispneia  Cianose
# 268       ausente  100            NaN      NaN
# 418     sistólico  160            NaN      NaN
# 443     sistólico   84  Assintomático      NaN
# 450     sistólico   80            NaN      NaN
# 536     Sistólico  NaN            NaN      NaN
# 626       ausente  300       Dispneia      NaN
# 696     sistólico   88            NaN      NaN
# 744    diastólico  NaN            NaN      NaN
# 1154     Contínuo   90       Dispneia      NaN
# 1254      ausente  NaN       Dispneia      NaN
# 5024    Sistólico   80  Assintomático      NaN
# 12562         NaN  NaN            NaN      NaN
# 12578         NaN  NaN            NaN      NaN
# 12581         NaN  NaN            NaN      NaN
# 12616         NaN  NaN            NaN      NaN
# 12688         NaN  NaN            NaN      NaN
# 12763         NaN  NaN            NaN      NaN
# 12767         NaN  NaN            NaN      NaN
#
#                                MOTIVO1                           MOTIVO2
# 57         6 - Suspeita de cardiopatia  6 - Alterações de pulso/perfusão
# 65         6 - Suspeita de cardiopatia                         6 - Sopro
# 84         6 - Suspeita de cardiopatia                         6 - Sopro
# 161        6 - Suspeita de cardiopatia                             Outro
# 167        6 - Suspeita de cardiopatia                         6 - Sopro
# 268        6 - Suspeita de cardiopatia                         6 - Sopro
# 418    1 - Cardiopatia já estabelecida                      5 - Cirurgia
# 443    1 - Cardiopatia já estabelecida         1 - Cardiopatia congenica
# 450        6 - Suspeita de cardiopatia                         6 - Sopro
# 536                                NaN                               NaN
# 626    1 - Cardiopatia já estabelecida         1 - Cardiopatia congenica
# 696    1 - Cardiopatia já estabelecida         1 - Cardiopatia congenica
# 744        6 - Suspeita de cardiopatia                             Outro
# 1154   1 - Cardiopatia já estabelecida         1 - Cardiopatia congenica
# 1254   1 - Cardiopatia já estabelecida         1 - Cardiopatia congenica
# 5024   1 - Cardiopatia já estabelecida         1 - Cardiopatia congenica
# 12562                              NaN                               NaN
# 12578                              NaN                               NaN
# 12581         5 - Parecer cardiológico    6 - HAS/dislipidemia/obesidade
# 12616                              NaN                               NaN
# 12688                              NaN                               NaN
# 12763                              NaN                               NaN
# 12767                              NaN                               NaN

# %%
lista_indices = [
    12562, 12578, 12581, 12590, 12607, 12616, 12634, 12636, 
    12662, 12667, 12688, 12708, 12738, 12748, 12758, 12763, 
    12767, 12782, 12803, 12833, 12839, 12855
]

df_copy.drop(index=lista_indices, inplace=True)

# %%
df_copy['PULSOS'].value_counts()
# Out:
# PULSOS
# Normais                11509
# Amplos                    52
# Femorais diminuidos       39
# Outro                     36
# Diminuídos                18
# NORMAIS                    2
# AMPLOS                     1
# Name: count, dtype: int64

# %%
df_copy['PULSOS'] = df_copy['PULSOS'].str.capitalize()
df_copy['PULSOS'] = np.where(df_copy['PULSOS'] == 'Normais', 0, 1)
df_copy['PULSOS'].value_counts()
# Out:
# PULSOS
# 0    11511
# 1      172
# Name: count, dtype: int64

# %%
df_copy.head()
# Out:
#    Peso  Altura   IMC Atendimento  IDADE  PULSOS  PA SISTOLICA  PA DIASTOLICA  \
# 0   5.0      51  19.0    11/05/06   0.12       0           NaN            NaN
# 1   3.5      50  14.0    25/05/05   0.02       0           NaN            NaN
# 2   0.0       0   NaN    12/06/01  -4.05       0           NaN            NaN
# 3   8.1      65  19.0    15/10/09   0.50       0           NaN            NaN
# 4  40.0     151  18.0    14/01/08  12.89       0           NaN            NaN
#
#              PPA NORMAL X ANORMAL      B2      SOPRO   FC           HDA 1  \
# 0  Não Calculado          Anormal  Normal  Sistólico  112      Palpitacao
# 1  Não Calculado          Anormal  Normal    ausente  128        Dispneia
# 2  Não Calculado          Anormal  Normal  Sistólico   88   Assintomático
# 3  Não Calculado          Anormal  Normal    ausente   92   Assintomático
# 4  Não Calculado          Anormal  Normal    ausente   96  Dor precordial
#
#   HDA2                      MOTIVO1                              MOTIVO2
# 0  NaN  6 - Suspeita de cardiopatia  6 - Palpitação/taquicardia/arritmia
# 1  NaN  6 - Suspeita de cardiopatia                         6 - Dispnéia
# 2  NaN                 2 - Check-up                                  NaN
# 3  NaN     5 - Parecer cardiológico                                  NaN
# 4  NaN     5 - Parecer cardiológico                                  NaN

# %% [markdown]
# ## Tratando coluna *Motivo 1 e 2*

# %%
df_copy['MOTIVO1'].isna().sum()
# Out:
# np.int64(1055)

# %%
df_copy['MOTIVO1'].value_counts()
# Out:
# MOTIVO1
# 5 - Parecer cardiológico           5352
# 6 - Suspeita de cardiopatia        4285
# 1 - Cardiopatia já estabelecida    1158
# 2 - Check-up                        701
# 7 - Outro                           322
# Name: count, dtype: int64

# %%
df_copy['MOTIVO2'].isna().sum()
# Out:
# np.int64(2676)

# %%
df_copy['MOTIVO2'].value_counts()
# Out:
# MOTIVO2
# 5 - Cirurgia                           2846
# 6 - Sopro                              2284
# 1 - Cardiopatia congenica              1018
# Outro                                   783
# 5 - Atividade física                    586
# 6 - Palpitação/taquicardia/arritmia     397
# 6 - Dor precordial                      369
# 6 - HAS/dislipidemia/obesidade          226
# 6 - Dispnéia                            216
# 6 - Cianose                             137
# 1 - Cardiopatia adquirida                90
# 6 - Cardiopatia na familia               32
# 5 - Uso de cisaprida                      9
# 6 - Cansaço                               6
# 6 - Alterações de pulso/perfusão          5
# 6 - Cianose e dispnéia                    3
# Name: count, dtype: int64

# %%
def limpar_motivo(valor):
    if pd.isna(valor):
        return np.nan
    
    texto = str(valor)

    texto_limpo = re.sub(r'^\d+\s*-\s*', '', texto)

    return texto_limpo.strip().lower()

df_copy['MOTIVO1'] = df_copy['MOTIVO1'].apply(limpar_motivo)
df_copy['MOTIVO2'] = df_copy['MOTIVO2'].apply(limpar_motivo)

df_copy['MOTIVO'] = df_copy['MOTIVO2'].fillna(df_copy['MOTIVO1'])

df_copy.drop(columns=['MOTIVO1', 'MOTIVO2'], inplace=True)
df_copy.head()
# Out:
#    Peso  Altura   IMC Atendimento  IDADE  PULSOS  PA SISTOLICA  PA DIASTOLICA  \
# 0   5.0      51  19.0    11/05/06   0.12       0           NaN            NaN
# 1   3.5      50  14.0    25/05/05   0.02       0           NaN            NaN
# 2   0.0       0   NaN    12/06/01  -4.05       0           NaN            NaN
# 3   8.1      65  19.0    15/10/09   0.50       0           NaN            NaN
# 4  40.0     151  18.0    14/01/08  12.89       0           NaN            NaN
#
#              PPA NORMAL X ANORMAL      B2      SOPRO   FC           HDA 1  \
# 0  Não Calculado          Anormal  Normal  Sistólico  112      Palpitacao
# 1  Não Calculado          Anormal  Normal    ausente  128        Dispneia
# 2  Não Calculado          Anormal  Normal  Sistólico   88   Assintomático
# 3  Não Calculado          Anormal  Normal    ausente   92   Assintomático
# 4  Não Calculado          Anormal  Normal    ausente   96  Dor precordial
#
#   HDA2                           MOTIVO
# 0  NaN  palpitação/taquicardia/arritmia
# 1  NaN                         dispnéia
# 2  NaN                         check-up
# 3  NaN             parecer cardiológico
# 4  NaN             parecer cardiológico

# %% [markdown]
# ## Tratando colunas *HDA 1 e 2*

# %%
df_copy['HDA 1'].isna().sum()
# Out:
# np.int64(3119)

# %%
df_copy['HDA 1'].value_counts()
# Out:
# HDA 1
# Assintomático      6532
# Dispneia            539
# Dor precordial      507
# Palpitacao          362
# Cianose             258
# Desmaio/tontura     155
# Outro               124
# Ganho de peso        87
# Name: count, dtype: int64

# %%
df_copy['HDA2'].isna().sum()
# Out:
# np.int64(11281)

# %%
df_copy['HDA2'].value_counts()
# Out:
# HDA2
# Palpitacao         83
# Dispneia           82
# Dor precordial     65
# Cianose            62
# Desmaio/tontura    49
# Outro              41
# Ganho de peso      19
# Assintomático       1
# Name: count, dtype: int64

# %%
def unir_sintomas(row):
    sintomas = set()

    if pd.notna(row['HDA 1']):
        sintoma1 = str(row['HDA 1']).strip().lower()
        if sintoma1 not in ['', 'nan']:
            sintomas.add(sintoma1)

    if pd.notna(row['HDA2']):
        sintoma2 = str(row['HDA2']).strip().lower()
        if sintoma2 not in ['', 'nan']:
            sintomas.add(sintoma2)

    return ",".join(sintomas) 

df_copy['HDA'] = df_copy.apply(unir_sintomas, axis=1)

df_copy.drop(columns=['HDA 1', 'HDA2'], inplace=True)

print("Coluna unida:")
print(df_copy['HDA'].head())
# Out:
# Coluna unida:
# 0        palpitacao
# 1          dispneia
# 2     assintomático
# 3     assintomático
# 4    dor precordial
# Name: HDA, dtype: object

# %%
df_copy.head()
# Out:
#    Peso  Altura   IMC Atendimento  IDADE  PULSOS  PA SISTOLICA  PA DIASTOLICA  \
# 0   5.0      51  19.0    11/05/06   0.12       0           NaN            NaN
# 1   3.5      50  14.0    25/05/05   0.02       0           NaN            NaN
# 2   0.0       0   NaN    12/06/01  -4.05       0           NaN            NaN
# 3   8.1      65  19.0    15/10/09   0.50       0           NaN            NaN
# 4  40.0     151  18.0    14/01/08  12.89       0           NaN            NaN
#
#              PPA NORMAL X ANORMAL      B2      SOPRO   FC  \
# 0  Não Calculado          Anormal  Normal  Sistólico  112
# 1  Não Calculado          Anormal  Normal    ausente  128
# 2  Não Calculado          Anormal  Normal  Sistólico   88
# 3  Não Calculado          Anormal  Normal    ausente   92
# 4  Não Calculado          Anormal  Normal    ausente   96
#
#                             MOTIVO             HDA
# 0  palpitação/taquicardia/arritmia      palpitacao
# 1                         dispnéia        dispneia
# 2                         check-up   assintomático
# 3             parecer cardiológico   assintomático
# 4             parecer cardiológico  dor precordial

# %% [markdown]
# ## Tratando coluna *PPA*

# %%
df_copy['PPA'].isna().sum()
# Out:
# np.int64(217)

# %%
df_copy['PPA'].value_counts()
# Out:
# PPA
# Não Calculado          8681
# Normal                 1790
# #VALUE!                 706
# HAS-2 PAS                73
# Pre-Hipertensão PAD      73
# Pre-Hipertensão PAS      48
# HAS-1 PAS                48
# HAS-1 PAD                26
# HAS-2 PAD                21
# Name: count, dtype: int64

# %%
df_copy['PA DIASTOLICA'].isna().sum()
# Out:
# np.int64(6562)
